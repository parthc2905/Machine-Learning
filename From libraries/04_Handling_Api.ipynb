# %% [markdown]
# # Handling data through api

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDNjOWFhYjc2YjI1NjkxYzAxZTFiZWIwZTU4OTZhYSIsIm5iZiI6MTc3MjEyODk0MC4wLCJzdWIiOiI2OWEwOGFhYjkxNjcyNzE2MjRlZmYxOTYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MVOtln2Ekezi-r9l_gAn75DBujp2abK97moUUQdNF1I"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/hYgUkH7TusddHRtelj53I6gFOWR.jpg","id":799882,"title":"The Bluff","original_title":"The Bluff","overview":"When her tranquil life on a remote island is shattered by the return of her vengeful former captain, a skilled ex-pirate must confront her bloody past and unleash her deadly talents to save her family from a ruthless siege.","poster_path":"/sojEzvfxR2DBcDSJyAisX8TWjov.jpg","media_type":"movie","original_language":"en","genre_ids":[28,53],"popularity":220.9528,"release_date":"2026-02-17","video":false,"vote_average":5.4,"vote_count":34},{"adult":false,"backdrop_path":"/yWCZc2TcsCYbMMjvUIsczmQi2TX.jpg","id":1159559,"title":"Scream 7","original_title":"Scream 7","overview":"When a new Ghostface killer emerges in the quiet town where Sidney Prescott has built a new life, her darkest fears are realized as her daughter becomes the next target. Determined to protect her family, Sidney must face the horrors of her past to put an end to the bloodshed once and for all.","poster_path":"/jjyuk0edLiW8vOSnlfwWCCLpbh5.jpg","media_type":"movie","original_language":"en","genre_ids":[27,9648,80],"popularity":88.308,"release_date":"2026-02-25","video":false,"vote_average":6.2,"vote_count":38},{"adult":false,"backdrop_path":"/6YjnTRBz704LF1uJ3ZC4wsS9T8r.jpg","id":1290821,"title":"Shelter","original_title":"Shelter","overview":"A man living in self-imposed exile on a remote island rescues a young girl from a violent storm, setting off a chain of events that forces him out of seclusion to protect her from enemies tied to his past.","poster_path":"/buPFnHZ3xQy6vZEHxbHgL1Pc6CR.jpg","media_type":"movie","original_language":"en","genre_ids":[28,80,53],"popularity":429.6689,"release_date":"2026-01-28","video":false,"vote_average":7.0,"vote_count":108},{"adult":false,"backdrop_path":"/73BClq9FOcrWrutnpiqhCNEWEwJ.jpg","id":858024,"title":"Hamnet","original_title":"Hamnet","overview":"The powerful story of love and loss that inspired the creation of Shakespeare's timeless masterpiece, Hamlet.","poster_path":"/vbeyOZm2bvBXcbgPD3v6o94epPX.jpg","media_type":"movie","original_language":"en","genre_ids":[18,10749,36],"popularity":67.8134,"release_date":"2025-11-26","video":false,"vote_average":7.7,"vote_count":742},{"adult":false,"backdrop_path":"/nTbO6UF944b0VZrgypMK5rFYRSW.jpg","id":680493,"title":"Return to Silent Hill","original_title":"Return to Silent Hill","overview":"When James receives a mysterious letter from his lost love Mary, he is drawn to Silent Hill—a once-familiar town now consumed by darkness. As he searches for her, James faces monstrous creatures and unravels a terrifying truth that will push him to the edge of his sanity.","poster_path":"/dOpnJnhABTw85CG80BhBdBH9Teh.jpg","media_type":"movie","original_language":"en","genre_ids":[9648,18,27],"popularity":115.0421,"release_date":"2026-01-21","video":false,"vote_average":5.105,"vote_count":195},{"adult":false,"backdrop_path":"/hHDNOlATHhre4eZ7aYz5cdyJLik.jpg","id":1272837,"title":"28 Years Later: The Bone Temple","original_title":"28 Years Later: The Bone Temple","overview":"Dr. Kelson finds himself in a shocking new relationship - with consequences that could change the world as they know it - and Spike's encounter with Jimmy Crystal becomes a nightmare he can't escape.","poster_path":"/kK1BGkG3KAvWB0WMV1DfOx9yTMZ.jpg","media_type":"movie","original_language":"en","genre_ids":[27,53,878],"popularity":195.106,"release_date":"2026-01-14","video":false,"vote_average":7.197,"vote_count":635},{"adult":false,"backdrop_path":"/2RrLuIfIzGWWIH8IAEo6o0IYHmx.jpg","id":1327819,"title":"Hoppers","original_title":"Hoppers","overview":"Scientists have discovered how to \"hop\" human consciousness into lifelike robotic animals, allowing people to communicate with animals as animals. Animal lover Mabel seizes an opportunity to use the technology, uncovering mysteries within the animal world that are beyond anything she could have imagined.","poster_pat ...

# %% [markdown]
# ## Converting response to Dataframe

# %%
import pandas as pd
df = pd.DataFrame(response.json()['results'], columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average', 'vote_count'])

# %%
df.head()
# Out:
#         id                  title  \
# 0   799882              The Bluff
# 1  1159559               Scream 7
# 2  1290821                Shelter
# 3   858024                 Hamnet
# 4   680493  Return to Silent Hill
#
#                                             overview  popularity release_date  \
# 0  When her tranquil life on a remote island is s...    220.9528   2026-02-17
# 1  When a new Ghostface killer emerges in the qui...     88.3080   2026-02-25
# 2  A man living in self-imposed exile on a remote...    429.6689   2026-01-28
# 3  The powerful story of love and loss that inspi...     67.8134   2025-11-26
# 4  When James receives a mysterious letter from h...    115.0421   2026-01-21
#
#    vote_average  vote_count
# 0         5.400          34
# 1         6.200          38
# 2         7.000         108
# 3         7.700         742
# 4         5.105         195

# %% [markdown]
# ## CREATING EMPTY DATAFRAME TO STORE DATA FROM RESPONSE

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Concatinating data into a dataframe by iteration

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDNjOWFhYjc2YjI1NjkxYzAxZTFiZWIwZTU4OTZhYSIsIm5iZiI6MTc3MjEyODk0MC4wLCJzdWIiOiI2OWEwOGFhYjkxNjcyNzE2MjRlZmYxOTYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MVOtln2Ekezi-r9l_gAn75DBujp2abK97moUUQdNF1I"
}

for i in range(1, 501):
    url = f"https://api.themoviedb.org/3/trending/movie/day?language=en-US&page={i}"
    response = requests.get(url, headers=headers)
    tempdf = pd.DataFrame(response.json()['results'], columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average', 'vote_count'])
    df = pd.concat([df,tempdf], ignore_index=True)

# %% [markdown]
# ## Storing the data to specified directory

# %%
df.to_csv('../Datasets/Movies.csv')
