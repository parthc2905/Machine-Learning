# %% [markdown]
# # Handling data through api

# %%
import requests

url = "https://api.themoviedb.org/3/trending/movie/day?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDNjOWFhYjc2YjI1NjkxYzAxZTFiZWIwZTU4OTZhYSIsIm5iZiI6MTc3MjEyODk0MC4wLCJzdWIiOiI2OWEwOGFhYjkxNjcyNzE2MjRlZmYxOTYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MVOtln2Ekezi-r9l_gAn75DBujp2abK97moUUQdNF1I"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/hYgUkH7TusddHRtelj53I6gFOWR.jpg","id":799882,"title":"The Bluff","original_title":"The Bluff","overview":"When her tranquil life on a remote island is shattered by the return of her vengeful former captain, a skilled ex-pirate must confront her bloody past and unleash her deadly talents to save her family from a ruthless siege.","poster_path":"/sojEzvfxR2DBcDSJyAisX8TWjov.jpg","media_type":"movie","original_language":"en","genre_ids":[28,53],"popularity":358.4436,"release_date":"2026-02-17","video":false,"vote_average":5.98,"vote_count":50},{"adult":false,"backdrop_path":"/yWCZc2TcsCYbMMjvUIsczmQi2TX.jpg","id":1159559,"title":"Scream 7","original_title":"Scream 7","overview":"When a new Ghostface killer emerges in the quiet town where Sidney Prescott has built a new life, her darkest fears are realized as her daughter becomes the next target. Determined to protect her family, Sidney must face the horrors of her past to put an end 
# ...

# %% [markdown]
# ## Converting response to Dataframe

# %%
import pandas as pd
df = pd.DataFrame(response.json()['results'], columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average', 'vote_count'])

# %%
df.head()
# Out:
#         id                   title  \
# 0   799882               The Bluff
# 1  1159559                Scream 7
# 2  1032892  In the Blink of an Eye
# 3  1290821                 Shelter
# 4  1236153                   Mercy
#
#                                             overview  popularity release_date  \
# 0  When her tranquil life on a remote island is s...    358.4436   2026-02-17
# 1  When a new Ghostface killer emerges in the qui...    118.8518   2026-02-25
# 2  Three storylines, spanning thousands of years,...      2.7171   2026-01-26
# 3  A man living in self-imposed exile on a remote...    434.2537   2026-01-28
# 4  In the near future, a detective stands on tria...    379.2699   2026-01-20
#
#    vote_average  vote_count
# 0         5.980          50
# 1         5.800          63
# 2         6.000           1
# 3         6.924         119
# 4         7.125         545

# %% [markdown]
# ## CREATING EMPTY DATAFRAME TO STORE DATA FROM RESPONSE

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## Concatinating data into a dataframe by iteration

# %%
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJkMDNjOWFhYjc2YjI1NjkxYzAxZTFiZWIwZTU4OTZhYSIsIm5iZiI6MTc3MjEyODk0MC4wLCJzdWIiOiI2OWEwOGFhYjkxNjcyNzE2MjRlZmYxOTYiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.MVOtln2Ekezi-r9l_gAn75DBujp2abK97moUUQdNF1I"
}

for i in range(1, 501):
    url = f"https://api.themoviedb.org/3/trending/movie/day?language=en-US&page={i}"
    response = requests.get(url, headers=headers)
    tempdf = pd.DataFrame(response.json()['results'], columns=['id', 'title', 'overview', 'popularity', 'release_date', 'vote_average', 'vote_count'])
    df = pd.concat([df,tempdf], ignore_index=True)

# %% [markdown]
# ## Storing the data to specified directory

# %%
df.to_csv('../Datasets/Movies.csv')
